# %%
# Normalization & Scaling
# Source: IT24102225_Normalization_scaling.ipynb
# Assigned to: IT24102225
# Description: Applies StandardScaler to numerical columns for Z-score standardization.

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler


start_time = time.time()
print("Starting Normalization & Scaling at", time.strftime("%H:%M:%S", time.localtime()))

# Load dataset with relative path
df = pd.read_csv('../results/outputs/cleaned_outliers_data.csv')
print("Dataset loaded. Shape:", df.shape)

# Identify numerical columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
# Apply Standardization (Z-score scaling)
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])
print("StandardScaler applied successfully.\n")

print(df.head(5))

# Simple Visualization: Histogram of Total_Score after scaling
plt.figure()
plt.hist(df['Total_Score'], bins=20, edgecolor='k')
plt.title('IT24102225: Distribution of Total Score after Scaling')
plt.xlabel('Total Score (scaled)')
plt.ylabel('Frequency')
plt.savefig('../results/eda_visualizations/eda_IT24102225_hist.png')
plt.close()

# Save output with relative path
df.to_csv('../results/outputs/scaled_data.csv', index=False)
print("Saved: scaled_data.csv")
print(f"\nRuntime: {time.time() - start_time:.2f} seconds")
print("Normalization & Scaling Task Complete.")
# Out:
# Starting Normalization & Scaling at 22:10:54
# Dataset loaded. Shape: (4696, 30)
# StandardScaler applied successfully.
#
#   Student_ID First_Name Last_Name                    Email       Age  \
# 0      S1000       Omar  Williams  student0@university.com  0.483316
# 1      S1001      Maria     Brown  student1@university.com -1.525670
# 2      S1002      Ahmed     Jones  student2@university.com  1.487809
# 3      S1004       John     Smith  student4@university.com  0.985563
# 4      S1005       Liam     Brown  student5@university.com -0.018931
#
#    Attendance (%)  Midterm_Score  Final_Score  Assignments_Avg  Quizzes_Avg  \
# 0        1.523671      -1.714087    -0.564794        -0.073857    -1.492524
# 1        1.547971      -0.760131     0.277392        -0.036247     1.630290
# 2        1.673634      -1.643657    -0.316645         0.773067    -1.712216
# 3       -1.111097      -0.997189    -0.438378        -0.493836     0.642716
# 4       -1.028479      -0.019184    -0.279773         0.912363    -1.555590
#
#    ...  Sleep_Hours_per_Night  Gender_Female  Gender_Male  \
# 0  ...               -0.42724           True        False
# 1  ...               -1.53364          False         True
# 2  ...               -0.28894          False         True
# 3  ...               -1.39534           True        False
# 4  ...               -0.63469          False         True
#
#    Department_Business  Department_CS  Department_Engineering  \
# 0                False          False                   False
# 1                 True          False                   False
# 2                False          False                    True
# 3                False           True                   False
# 4                False          False                   False
#
#    Department_Mathematics  Average_Score  Study_Efficiency  Stress_Sleep_Ratio
# 0                    True      -1.127199          0.522054           -1.393790
# 1                   False       1.722651         -0.752275            0.084094
# 2                   False      -1.709141          0.360826            1.143204
# 3                   False       0.109371          0.318644            0.867194
# 4                    True      -0.363653         -0.903591            0.358394
#
# [5 rows x 30 columns]
# Saved: scaled_data.csv
#
# Runtime: 0.82 seconds
# Normalization & Scaling Task Complete.
